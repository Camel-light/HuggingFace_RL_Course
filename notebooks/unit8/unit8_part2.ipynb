# %% [markdown]
# # Unit 8 Part 2: Advanced Deep Reinforcement Learning. Using Sample Factory to play Doom from pixels
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/thumbnail2.png" alt="Thumbnail"/>
#
# In this notebook, we will learn how to train a Deep Neural Network to collect objects in a 3D environment based on the game of Doom, a video of the resulting policy is shown below. We train this policy using [Sample Factory](https://www.samplefactory.dev/), an asynchronous implementation of the PPO algorithm.
#
# Please note the following points:
#
# *   [Sample Factory](https://www.samplefactory.dev/) is an advanced RL framework and **only functions on Linux and Mac** (not Windows).
#
# *  The framework performs best on a **GPU machine with many CPU cores**, where it can achieve speeds of 100k interactions per second. The resources available on a standard Colab notebook **limit the performance of this library**. So the speed in this setting **does not reflect the real-world performance**.
# * Benchmarks for Sample Factory are available in a number of settings, check out the [examples](https://github.com/alex-petrenko/sample-factory/tree/master/sf_examples) if you want to find out more.

# %%
from IPython.display import HTML

HTML('''<video width="640" height="480" controls>
  <source src="https://huggingface.co/edbeeching/doom_health_gathering_supreme_3333/resolve/main/replay.mp4"
  type="video/mp4">Your browser does not support the video tag.</video>'''
)

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push one model:
#
# - `doom_health_gathering_supreme` get a result of >= 5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# If you don't find your model, **go to the bottom of the page and click on the refresh button**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Sample Factory
#
# [Sample Factory](https://www.samplefactory.dev/) is one of the **fastest RL libraries focused on very efficient synchronous and asynchronous implementations of policy gradients (PPO)**.
#
# Sample Factory is thoroughly **tested, used by many researchers and practitioners**, and is actively maintained. Our implementation is known to **reach SOTA performance in a variety of domains while minimizing RL experiment training time and hardware requirements**.
#
#
#
# ### Key features
#
# - Highly optimized algorithm [architecture](https://www.samplefactory.dev/06-architecture/overview/) for maximum learning throughput
# - [Synchronous and asynchronous](https://www.samplefactory.dev/07-advanced-topics/sync-async/) training regimes
# - [Serial (single-process) mode](https://www.samplefactory.dev/07-advanced-topics/serial-mode/) for easy debugging
# - Optimal performance in both CPU-based and [GPU-accelerated environments](https://www.samplefactory.dev/09-environment-integrations/isaacgym/)
# - Single- & multi-agent training, self-play, supports [training multiple policies](https://www.samplefactory.dev/07-advanced-topics/multi-policy-training/) at once on one or many GPUs
# - Population-Based Training ([PBT](https://www.samplefactory.dev/07-advanced-topics/pbt/))
# - Discrete, continuous, hybrid action spaces
# - Vector-based, image-based, dictionary observation spaces
# - Automatically creates a model architecture by parsing action/observation space specification. Supports [custom model architectures](https://www.samplefactory.dev/03-customization/custom-models/)
# - Designed to be imported into other projects, [custom environments](https://www.samplefactory.dev/03-customization/custom-environments/) are first-class citizens
# - Detailed [WandB and Tensorboard summaries](https://www.samplefactory.dev/05-monitoring/metrics-reference/), [custom metrics](https://www.samplefactory.dev/05-monitoring/custom-metrics/)
# - [HuggingFace 🤗 integration](https://www.samplefactory.dev/10-huggingface/huggingface/) (upload trained models and metrics to the Hub)
# - [Multiple](https://www.samplefactory.dev/09-environment-integrations/mujoco/) [example](https://www.samplefactory.dev/09-environment-integrations/atari/) [environment](https://www.samplefactory.dev/09-environment-integrations/vizdoom/) [integrations](https://www.samplefactory.dev/09-environment-integrations/dmlab/) with tuned parameters and trained models
#
# All of the above policies are available on the 🤗 hub. Search for the tag [sample-factory](https://huggingface.co/models?library=sample-factory&sort=downloads)
#
# ### How sample-factory works
#
# It works by **spawning multiple processes that run rollout workers, inference workers and a learner worker**.
#
# The *workers* **communicate through shared memory, which lowers the communication cost between processes**.
#
# The *rollout workers* interact with the environment and send observations to the *inference workers*.
#
# The *inferences workers* query a fixed version of the policy and **send actions back to the rollout worker**.
#
# After *k* steps the rollout works send a trajectory of experience to the learner worker, **which it uses to update the agent’s policy network**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/samplefactory.png" alt="Sample factory"/>

# %% [markdown]
# ### Actor Critic models in Sample-factory
#
# Actor Critic models in Sample Factory are composed of three components:
#
# - **Encoder** - Process input observations (images, vectors) and map them to a vector. This is the part of the model you will most likely want to customize.
# - **Core** - Intergrate vectors from one or more encoders, can optionally include a single- or multi-layer LSTM/GRU in a memory-based agent.
# - **Decoder** - Apply additional layers to the output of the model core before computing the policy and value outputs.
#
# The library has been designed to automatically support any observation and action spaces. Users can easily add their custom models. You can find out more in the [documentation](https://www.samplefactory.dev/03-customization/custom-models/#actor-critic-models-in-sample-factory).

# %% [markdown]
# ## ViZDoom
#
# [ViZDoom](https://vizdoom.cs.put.edu.pl/) is an **open-source python interface for the Doom Engine**.
#
# The library was created in 2016 by Marek Wydmuch, Michal Kempka  at the Institute of Computing Science, Poznan University of Technology, Poland.
#
# The library enables the **training of agents directly from the screen pixels in a number of scenarios**, including team deathmatch, shown in the video below. Because the ViZDoom environment is based on a game the was created in the 90s, it can be run on modern hardware at accelerated speeds, **allowing us to learn complex AI behaviors fairly quickly**.
#
# The library includes feature such as:
#
# - Multi-platform (Linux, macOS, Windows),
# - API for Python and C++,
# - [OpenAI Gym](https://www.gymlibrary.dev/) environment wrappers
# - Easy-to-create custom scenarios (visual editors, scripting language, and examples available),
# - Async and sync single-player and multiplayer modes,
# - Lightweight (few MBs) and fast (up to 7000 fps in sync mode, single-threaded),
# - Customizable resolution and rendering parameters,
# - Access to the depth buffer (3D vision),
# - Automatic labeling of game objects visible in the frame,
# - Access to the audio buffer
# - Access to the list of actors/objects and map geometry,
# - Off-screen rendering and episode recording,
# - Time scaling in async mode.

# %% [markdown]
# ## We first need to install some dependencies that are required for the ViZDoom environment

# %%
# %%capture
# %%bash
# Install ViZDoom deps from
# https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md#-linux

apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev \
nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev \
libopenal-dev timidity libwildmidi-dev unzip ffmpeg

# Boost libraries
apt-get install libboost-all-dev

# Lua binding dependencies
apt-get install liblua5.1-dev

# %% [markdown]
# ## Then we can install Sample Factory and ViZDoom

# %%
# install python libraries
# !pip install faster-fifo==1.4.2
# !pip install vizdoom
# Out:
# Collecting faster-fifo==1.4.2
#   Downloading faster-fifo-1.4.2.tar.gz (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=45.2.0 in /usr/local/lib/python3.11/dist-packages (from faster-fifo==1.4.2) (75.1.0)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.11/dist-packages (from faster-fifo==1.4.2) (3.0.11)
# Building wheels for collected packages: faster-fifo
#   Building wheel for faster-fifo (pyproject.toml) ... done
#   Created wheel for faster-fifo: filename=faster_fifo-1.4.2-cp311-cp311-linux_x86_64.whl size=347988 sha256=0651c85cf15d88fe046025576d83eb3b0a033b38d3a8a78125a171a84ddefa50
#   Stored in directory: /root/.cache/pip/wheels/9b/87/68/41379e7d255d002b3558ec863e1bd0ac87535edf1d3fdc3f64
# Successfully built faster-fifo
# Installing collected packages: faster-fifo
# Successfully installed faster-fifo-1.4.2
# Collecting vizdoom
#   Downloading vizdoom-1.2.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from vizdoom) (1.26.4)
# Collecting gymnasium>=0.28.0 (from vizdoom)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from vizdoom) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.0->vizdoom) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.28.0->vizdoom)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading vizdoom-1.2.4-cp311-cp311-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 79.8 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 64.6 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, vizdoom
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0 vizdoom-1.2.4

# %%
# !pip install sample-factory==2.1.1
# Out:
# Collecting sample-factory==2.1.1
#   Downloading sample_factory-2.1.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2.0,>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (1.26.4)
# Requirement already satisfied: torch!=1.13.0,<3.0,>=1.9 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (2.5.1+cu121)
# Collecting gymnasium<1.0,>=0.27 (from sample-factory==2.1.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting pyglet (from sample-factory==2.1.1)
#   Downloading pyglet-2.1.1-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tensorboard>=1.15.0 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (2.17.1)
# Collecting tensorboardx>=2.0 (from sample-factory==2.1.1)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (5.9.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (3.5.0)
# Collecting colorlog (from sample-factory==2.1.1)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting signal-slot-mp<2.0,>=1.0.3 (from sample-factory==2.1.1)
#   Downloading signal_slot_mp-1.0.5-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (3.16.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (4.10.0.84)
# Requirement already satisfied: wandb>=0.12.9 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (0.19.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from sample-factory==2.1.1) (0.27.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.0,>=0.27->sample-factory==2.1.1) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.0,>=0.27->sample-factory==2.1.1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.0,>=0.27->sample-factory==2.1.1) (0.0.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (4.67.1)
# Collecting faster-fifo<2.0,>=1.4.4 (from signal-slot-mp<2.0,>=1.0.3->sample-factory==2.1.1)
#   Downloading faster_fifo-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=1.15.0->sample-factory==2.1.1) (3.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch!=1.13.0,<3.0,>=1.9->sample-factory==2.1.1) (1.3.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (4.3.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (2.10.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.12.9->sample-factory==2.1.1) (1.3.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory==2.1.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.12.9->sample-factory==2.1.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.12.9->sample-factory==2.1.1) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory==2.1.1) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15.0->sample-factory==2.1.1) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory==2.1.1) (5.0.2)
# Downloading sample_factory-2.1.1-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 29.4 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 70.9 MB/s eta 0:00:00
# Downloading signal_slot_mp-1.0.5-py3-none-any.whl (13 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.1 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading pyglet-2.1.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.9/961.9 kB 65.7 MB/s eta 0:00:00
# Downloading faster_fifo-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.2/423.2 kB 41.3 MB/s eta 0:00:00
# Installing collected packages: tensorboardx, pyglet, gymnasium, faster-fifo, colorlog, signal-slot-mp, sample-factory
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0
#     Uninstalling gymnasium-1.0.0:
#       Successfully uninstalled gymnasium-1.0.0
#   Attempting uninstall: faster-fifo
#     Found existing installation: faster-fifo 1.4.2
#     Uninstalling faster-fifo-1.4.2:
#       Successfully uninstalled faster-fifo-1.4.2
# Successfully installed colorlog-6.9.0 faster-fifo-1.5.2 gymnasium-0.29.1 pyglet-2.1.1 sample-factory-2.1.1 signal-slot-mp-1.0.5 tensorboardx-2.6.2.2

# %% [markdown]
# ## Setting up the Doom Environment in sample-factory

# %%
import functools

from sample_factory.algo.utils.context import global_model_factory
from sample_factory.cfg.arguments import parse_full_cfg, parse_sf_args
from sample_factory.envs.env_utils import register_env
from sample_factory.train import run_rl

from sf_examples.vizdoom.doom.doom_model import make_vizdoom_encoder
from sf_examples.vizdoom.doom.doom_params import add_doom_env_args, doom_override_defaults
from sf_examples.vizdoom.doom.doom_utils import DOOM_ENVS, make_doom_env_from_spec


# Registers all the ViZDoom environments
def register_vizdoom_envs():
    for env_spec in DOOM_ENVS:
        make_env_func = functools.partial(make_doom_env_from_spec, env_spec)
        register_env(env_spec.name, make_env_func)

# Sample Factory allows the registration of a custom Neural Network architecture
# See https://github.com/alex-petrenko/sample-factory/blob/master/sf_examples/vizdoom/doom/doom_model.py for more details
def register_vizdoom_models():
    global_model_factory().register_encoder_factory(make_vizdoom_encoder)


def register_vizdoom_components():
    register_vizdoom_envs()
    register_vizdoom_models()

# parse the command line args and create a config
def parse_vizdoom_cfg(argv=None, evaluation=False):
    parser, _ = parse_sf_args(argv=argv, evaluation=evaluation)
    # parameters specific to Doom envs
    add_doom_env_args(parser)
    # override Doom default values for algo parameters
    doom_override_defaults(parser)
    # second parsing pass yields the final configuration
    final_cfg = parse_full_cfg(parser, argv)
    return final_cfg

# %% [markdown]
# Now that the setup if complete, we can train the agent. We have chosen here to learn a ViZDoom task called `Health Gathering Supreme`.
#
# ### The scenario: Health Gathering Supreme
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/Health-Gathering-Supreme.png" alt="Health-Gathering-Supreme"/>
#
#
#
# The objective of this scenario is to **teach the agent how to survive without knowing what makes him survive**. Agent know only that **life is precious** and death is bad so **it must learn what prolongs his existence and that his health is connected with it**.
#
# Map is a rectangle containing walls and with a green, acidic floor which **hurts the player periodically**. Initially there are some medkits spread uniformly over the map. A new medkit falls from the skies every now and then. **Medkits heal some portions of player's health** - to survive agent needs to pick them up. Episode finishes after player's death or on timeout.
#
# Further configuration:
# - Living_reward = 1
# - 3 available buttons: turn left, turn right, move forward
# - 1 available game variable: HEALTH
# - death penalty = 100
#
# You can find out more about the scenarios available in ViZDoom [here](https://github.com/Farama-Foundation/ViZDoom/tree/master/scenarios).
#
# There are also a number of more complex scenarios that have been create for ViZDoom, such as the ones detailed on [this github page](https://github.com/edbeeching/3d_control_deep_rl).

# %% [markdown]
# ## Training the agent
# - We're going to train the agent for 4000000 steps it will take approximately 20min

# %%
## Start the training, this should take around 15 minutes
register_vizdoom_components()

# The scenario we train on today is health gathering
# other scenarios include "doom_basic", "doom_two_colors_easy", "doom_dm", "doom_dwango5", "doom_my_way_home", "doom_deadly_corridor", "doom_defend_the_center", "doom_defend_the_line"
env = "doom_health_gathering_supreme"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=8", "--num_envs_per_worker=4", "--train_for_env_steps=3800000"])

status = run_rl(cfg)
# Out:
# [2025-01-22 16:18:46,934][00571] register_encoder_factory: <function make_vizdoom_encoder at 0x7b8881bce700>
# [2025-01-22 16:18:46,954][00571] Saved parameter configuration for experiment default_experiment not found!
# [2025-01-22 16:18:46,956][00571] Starting experiment from scratch!
# [2025-01-22 16:18:46,966][00571] Experiment dir /content/train_dir/default_experiment already exists!
# [2025-01-22 16:18:46,966][00571] Resuming existing experiment from /content/train_dir/default_experiment...
# [2025-01-22 16:18:46,969][00571] Weights and Biases integration disabled
# [2025-01-22 16:18:49,668][00571] Queried available GPUs: 0
#
# [2025-01-22 16:18:49,670][00571] Environment var CUDA_VISIBLE_DEVICES is 0
#
# [2025-01-22 16:18:51,744][00571] Automatically setting recurrence to 32
# [2025-01-22 16:18:51,746][00571] Starting experiment with the following configuration:
# help=False
# algo=APPO
# env=doom_health_gathering_supreme
# experiment=default_experiment
# train_dir=/content/train_dir
# restart_behavior=resume
# device=gpu
# seed=None
# num_policies=1
# async_rl=True
# serial_mode=False
# batched_sampling=False
# num_batches_to_accumulate=2
# worker_num_splits=2
# policy_workers_per_policy=1
# max_policy_lag=1000
# num_workers=8
# num_envs_per_worker=4
# batch_size=1024
# num_batches_per_epoch=1
# num_epochs=1
# rollout=32
# recurrence=32
# shuffle_minibatches=False
# gamma=0.99
# reward_scale=1.0
# reward_clip=1000.0
# value_bootstrap=False
# normalize_returns=True
# exploration_loss_coeff=0.001
# value_loss_coeff=0.5
# kl_loss_coeff=0.0
# exploration_loss=symmetric_kl
# gae_lambda=0.95
# ppo_clip_ratio=0.1
# ppo_clip_value=0.2
# with_vtrace=False
# vtrace_rho=1.0
# vtrace_c=1.0
# optimizer=adam
# adam_eps=1e-06
# adam_beta1=0.9
# adam_beta2=0.999
# max_grad_norm=4.0
# learning_rate=0.0001
# lr_schedule=constant
# lr_schedule_kl_threshold=0.008
# lr_adaptive_min=1e-06
# lr_adaptive_max=0.01
# obs_subtract_mean=0.0
# obs_scale=255.0
# normalize_input=True
# normalize_input_keys=None
# decorrelate_experience_max_seconds=0
# decorrelate_envs_on_one_worker=True
# actor_worker_gpus=[]
# set_workers_cpu_affinity=True
# force_envs_single_thread=False
# default_niceness=0
# log_to_file=True
# experiment_summaries_interval=10
# flush_summaries_interval=30
# stats_avg=100
# summaries_use_frameskip=True
# heartbeat_interval=20
# heartbeat_reporting_interval=600
# train_for_env_steps=3800000
# train_for_seconds=10000000000
# save_every_sec=120
# keep_checkpoints=2
# load_checkpoint_kind=latest
# save_milestones_sec=-1
# save_best_every_sec=5
# save_best_metric=reward
# save_best_after=100000
# benchmark=False
# encoder_mlp_layers=[512, 512]
# encoder_conv_architecture=convnet_simple
# encoder_conv_mlp_layers=[512]
# use_rnn=True
# rnn_size=512
# rnn_type=gru
# rnn_num_layers=1
# decoder_mlp_layers=[]
# nonlinearity=elu
# policy_initialization=orthogonal
# policy_init_gain=1.0
# actor_critic_share_weights=True
# adaptive_stddev=True
# continuous_tanh_scale=0.0
# initial_stddev=1.0
# use_env_info_cache=False
# env_gpu_actions=False
# env_gpu_observations=True
# env_frameskip=4
# env_framestack=1
# pixel_format=CHW
# use_record_episode_statistics=False
# with_wandb=False
# wandb_user=None
# wandb_project=sample_factory
# wandb_group=None
# wandb_job_type=SF
# wandb_tags=[]
# with_pbt=False
# pbt_mix_policies_in_one_env=True
# pbt_period_env_steps=5000000
# pbt_start_mutation=20000000
# pbt_replace_fraction=0.3
# pbt_mutation_rate=0.15
# pbt_replace_reward_gap=0.1
# pbt_replace_reward_gap_absolute=1e-06
# pbt_optimize_gamma=False
# pbt_target_objective=true_objective
# pbt_perturb_min=1.1
# pbt_perturb_max=1.5
# num_agents=-1
# num_humans=0
# num_bots=-1
# start_bot_difficulty=None
# timelimit=None
# res_w=128
# res_h=72
# wide_aspect_ratio=False
# eval_env_frameskip=1
# fps=35
# command_line=--env=doom_health_gathering_supreme --num_workers=8 --num_envs_per_worker=4 --train_for_env_steps=3800000
# cli_args={'env': 'doom_health_gathering_supreme', 'num_workers': 8, 'num_envs_per_worker': 4, 'train_for_env_steps': 3800000}
# git_hash=unknown
# git_repo_name=not a git repository
# [2025-01-22 16:18:51,749][00571] Saving configuration to /content/train_dir/default_experiment/config.json...
# [2025-01-22 16:18:51,752][00571] Rollout worker 0 uses device cpu
# [2025-01-22 16:18:51,753][00571] Rollout worker 1 uses device cpu
# [2025-01-22 16:18:51,754][00571] Rollout worker 2 uses device cpu
# [2025-01-22 16:18:51,755][00571] Rollout worker 3 uses device cpu
# [2025-01-22 16:18:51,756][00571] Rollout worker 4 uses device cpu
# [2025-01-22 16:18:51,757][00571] Rollout worker 5 uses device cpu
# [2025-01-22 16:18:51,758][00571] Rollout worker 6 uses device cpu
# [2025-01-22 16:18:51,759][00571] Rollout worker 7 uses device cpu
# [2025-01-22 16:18:51,907][00571] Using GPUs [0] for process 0 (actually maps to GPUs [0])
# [2025-01-22 16:18:51,910][00571] InferenceWorker_p0-w0: min num requests: 2
# [2025-01-22 16:18:51,941][00571] Starting all processes...
# [2025-01-22 16:18:51,942][00571] Starting process learner_proc0
# [2025-01-22 16:18:51,986][00571] Starting all processes...
# [2025-01-22 16:18:51,993][00571] Starting process inference_proc0-0
# [2025-01-22 16:18:51,993][00571] Starting process rollout_proc0
# [2025-01-22 16:18:51,995][00571] Starting process rollout_proc1
# [2025-01-22 16:18:51,995][00571] Starting process rollout_proc2
# [2025-01-22 16:18:51,996][00571] Starting process rollout_proc3
# [2025-01-22 16:18:52,011][00571] Starting process rollout_proc4
# [2025-01-22 16:18:52,012][00571] Starting process rollout_proc5
# [2025-01-22 16:18:52,012][00571] Starting process rollout_proc6
# [2025-01-22 16:18:52,012][00571] Starting process rollout_proc7
# [2025-01-22 16:19:11,903][00571] Heartbeat connected on Batcher_0
# [2025-01-22 16:19:11,908][00571] Heartbeat connected on InferenceWorker_p0-w0
# [2025-01-22 16:19:11,916][00571] Heartbeat connected on RolloutWorker_w0
# [2025-01-22 16:19:11,922][00571] Heartbeat connected on RolloutWorker_w1
# [2025-01-22 16:19:11,923][00571] Heartbeat connected on RolloutWorker_w2
# [2025-01-22 16:19:11,928][00571] Heartbeat connected on RolloutWorker_w3
# [2025-01-22 16:19:11,930][00571] Heartbeat connected on RolloutWorker_w4
# [2025-01-22 16:19:11,935][00571] Heartbeat connected on RolloutWorker_w5
# [2025-01-22 16:19:11,941][00571] Heartbeat connected on RolloutWorker_w6
# [2025-01-22 16:19:11,944][00571] Heartbeat connected on RolloutWorker_w7
# [2025-01-22 16:19:13,140][00571] Heartbeat connected on LearnerWorker_p0
# [2025-01-22 16:19:13,357][00571] Inference worker 0-0 is ready!
# [2025-01-22 16:19:13,359][00571] All inference workers are ready! Signal rollout workers to start!
# [2025-01-22 16:19:16,974][00571] Fps is (10 sec: nan, 60 sec: nan, 300 sec: nan). Total num frames: 0. Throughput: 0: nan. Samples: 0. Policy #0 lag: (min: -1.0, avg: -1.0, max: -1.0)
# [2025-01-22 16:19:21,974][00571] Fps is (10 sec: 0.0, 60 sec: 0.0, 300 sec: 0.0). Total num frames: 0. Throughput: 0: 2.4. Samples: 12. Policy #0 lag: (min: -1.0, avg: -1.0, max: -1.0)
# [2025-01-22 16:19:21,977][00571] Avg episode reward: [(0, '2.566')]
# [2025-01-22 16:19:26,974][00571] Fps is (10 sec: 0.0, 60 sec: 0.0, 300 sec: 0.0). Total num frames: 0. Throughput: 0: 192.8. Samples: 1928. Policy #0 lag: (min: -1.0, avg: -1.0, max: -1.0)
# [2025-01-22 16:19:26,978][00571] Avg episode reward: [(0, '3.032')]
# [2025-01-22 16:19:31,973][00571] Fps is (10 sec: 1638.4, 60 sec: 1092.3, 300 sec: 1092.3). Total num frames: 16384. Throughput: 0: 285.3. Samples: 4280. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:19:31,978][00571] Avg episode reward: [(0, '3.362')]
# [2025-01-22 16:19:36,973][00571] Fps is (10 sec: 4096.0, 60 sec: 2048.0, 300 sec: 2048.0). Total num frames: 40960. Throughput: 0: 395.6. Samples: 7912. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:19:36,976][00571] Avg episode reward: [(0, '3.928')]
# [2025-01-22 16:19:41,974][00571] Fps is (10 sec: 4096.0, 60 sec: 2293.8, 300 sec: 2293.8). Total num frames: 57344. Throughput: 0: 582.5. Samples: 14562. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:19:41,976][00571] Avg episode reward: [(0, '4.365')]
# [2025-01-22 16:19:46,974][00571] Fps is (10 sec: 3276.8, 60 sec: 2457.6, 300 sec: 2457.6). Total num frames: 73728. Throughput: 0: 637.7. Samples: 19132. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:19:46,975][00571] Avg episode reward: [(0, '4.417')]
# [2025-01-22 16:19:51,973][00571] Fps is (10 sec: 4096.0, 60 sec: 2808.7, 300 sec: 2808.7). Total num frames: 98304. Throughput: 0: 650.4. Samples: 22764. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:19:51,986][00571] Avg episode reward: [(0, '4.173')]
# [2025-01-22 16:19:56,974][00571] Fps is (10 sec: 4505.6, 60 sec: 2969.6, 300 sec: 2969.6). Total num frames: 118784. Throughput: 0: 742.8. Samples: 29714. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:19:56,981][00571] Avg episode reward: [(0, '4.392')]
# [2025-01-22 16:20:01,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3003.7, 300 sec: 3003.7). Total num frames: 135168. Throughput: 0: 768.6. Samples: 34586. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:20:01,978][00571] Avg episode reward: [(0, '4.506')]
# [2025-01-22 16:20:06,974][00571] Fps is (10 sec: 4095.9, 60 sec: 3194.9, 300 sec: 3194.9). Total num frames: 159744. Throughput: 0: 829.3. Samples: 37330. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:20:06,976][00571] Avg episode reward: [(0, '4.432')]
# [2025-01-22 16:20:11,974][00571] Fps is (10 sec: 4915.1, 60 sec: 3351.3, 300 sec: 3351.3). Total num frames: 184320. Throughput: 0: 950.9. Samples: 44718. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:20:11,978][00571] Avg episode reward: [(0, '4.456')]
# [2025-01-22 16:20:16,975][00571] Fps is (10 sec: 4095.6, 60 sec: 3345.0, 300 sec: 3345.0). Total num frames: 200704. Throughput: 0: 1029.0. Samples: 50588. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:20:16,978][00571] Avg episode reward: [(0, '4.284')]
# [2025-01-22 16:20:21,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3618.1, 300 sec: 3339.8). Total num frames: 217088. Throughput: 0: 999.3. Samples: 52882. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:20:21,979][00571] Avg episode reward: [(0, '4.286')]
# [2025-01-22 16:20:26,973][00571] Fps is (10 sec: 4096.5, 60 sec: 4027.7, 300 sec: 3452.3). Total num frames: 241664. Throughput: 0: 1004.0. Samples: 59742. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:20:26,976][00571] Avg episode reward: [(0, '4.440')]
# [2025-01-22 16:20:31,979][00571] Fps is (10 sec: 4912.4, 60 sec: 4163.9, 300 sec: 3549.6). Total num frames: 266240. Throughput: 0: 1057.5. Samples: 66724. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:20:31,981][00571] Avg episode reward: [(0, '4.518')]
# [2025-01-22 16:20:36,978][00571] Fps is (10 sec: 3684.7, 60 sec: 3959.2, 300 sec: 3481.4). Total num frames: 278528. Throughput: 0: 1024.7. Samples: 68882. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:20:36,981][00571] Avg episode reward: [(0, '4.554')]
# [2025-01-22 16:20:41,974][00571] Fps is (10 sec: 3688.5, 60 sec: 4096.0, 300 sec: 3565.9). Total num frames: 303104. Throughput: 0: 1002.9. Samples: 74846. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:20:41,976][00571] Avg episode reward: [(0, '4.563')]
# [2025-01-22 16:20:46,974][00571] Fps is (10 sec: 4917.5, 60 sec: 4232.5, 300 sec: 3640.9). Total num frames: 327680. Throughput: 0: 1051.9. Samples: 81922. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:20:46,976][00571] Avg episode reward: [(0, '4.381')]
# [2025-01-22 16:20:51,974][00571] Fps is (10 sec: 3686.2, 60 sec: 4027.7, 300 sec: 3578.6). Total num frames: 339968. Throughput: 0: 1051.0. Samples: 84626. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:20:51,977][00571] Avg episode reward: [(0, '4.442')]
# [2025-01-22 16:20:56,974][00571] Fps is (10 sec: 3276.8, 60 sec: 4027.7, 300 sec: 3604.5). Total num frames: 360448. Throughput: 0: 991.4. Samples: 89330. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:20:56,976][00571] Avg episode reward: [(0, '4.373')]
# [2025-01-22 16:21:01,974][00571] Fps is (10 sec: 4505.9, 60 sec: 4164.3, 300 sec: 3666.9). Total num frames: 385024. Throughput: 0: 1020.8. Samples: 96524. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:21:01,978][00571] Avg episode reward: [(0, '4.655')]
# [2025-01-22 16:21:06,974][00571] Fps is (10 sec: 4505.3, 60 sec: 4096.0, 300 sec: 3686.4). Total num frames: 405504. Throughput: 0: 1048.9. Samples: 100082. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:21:06,979][00571] Avg episode reward: [(0, '4.573')]
# [2025-01-22 16:21:11,975][00571] Fps is (10 sec: 3685.8, 60 sec: 3959.4, 300 sec: 3668.5). Total num frames: 421888. Throughput: 0: 1001.9. Samples: 104828. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:21:11,977][00571] Avg episode reward: [(0, '4.490')]
# [2025-01-22 16:21:16,974][00571] Fps is (10 sec: 3686.7, 60 sec: 4027.8, 300 sec: 3686.4). Total num frames: 442368. Throughput: 0: 991.7. Samples: 111346. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:21:16,980][00571] Avg episode reward: [(0, '4.559')]
# [2025-01-22 16:21:21,974][00571] Fps is (10 sec: 4506.2, 60 sec: 4164.3, 300 sec: 3735.5). Total num frames: 466944. Throughput: 0: 1025.8. Samples: 115038. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:21:21,978][00571] Avg episode reward: [(0, '4.518')]
# [2025-01-22 16:21:26,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4027.7, 300 sec: 3717.9). Total num frames: 483328. Throughput: 0: 1017.8. Samples: 120648. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:21:26,983][00571] Avg episode reward: [(0, '4.644')]
# [2025-01-22 16:21:31,978][00571] Fps is (10 sec: 3684.7, 60 sec: 3959.5, 300 sec: 3731.8). Total num frames: 503808. Throughput: 0: 985.1. Samples: 126256. Policy #0 lag: (min: 0.0, avg: 0.4, max: 1.0)
# [2025-01-22 16:21:31,981][00571] Avg episode reward: [(0, '4.633')]
# [2025-01-22 16:21:36,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.6, 300 sec: 3774.2). Total num frames: 528384. Throughput: 0: 1007.0. Samples: 129940. Policy #0 lag: (min: 0.0, avg: 0.7, max: 1.0)
# [2025-01-22 16:21:36,976][00571] Avg episode reward: [(0, '4.648')]
# [2025-01-22 16:21:41,978][00571] Fps is (10 sec: 4505.9, 60 sec: 4095.7, 300 sec: 3785.2). Total num frames: 548864. Throughput: 0: 1054.1. Samples: 136770. Policy #0 lag: (min: 0.0, avg: 0.7, max: 1.0)
# [2025-01-22 16:21:41,980][00571] Avg episode reward: [(0, '4.751')]
# [2025-01-22 16:21:46,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3891.2, 300 sec: 3741.0). Total num frames: 561152. Throughput: 0: 994.6. Samples: 141282. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:21:46,977][00571] Avg episode reward: [(0, '4.743')]
# [2025-01-22 16:21:51,973][00571] Fps is (10 sec: 3687.9, 60 sec: 4096.1, 300 sec: 3778.9). Total num frames: 585728. Throughput: 0: 996.6. Samples: 144930. Policy #0 lag: (min: 0.0, avg: 0.8, max: 2.0)
# [2025-01-22 16:21:51,980][00571] Avg episode reward: [(0, '4.504')]
# [2025-01-22 16:21:56,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4164.3, 300 sec: 3814.4). Total num frames: 610304. Throughput: 0: 1049.8. Samples: 152066. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:21:56,977][00571] Avg episode reward: [(0, '4.445')]
# [2025-01-22 16:22:01,975][00571] Fps is (10 sec: 4095.3, 60 sec: 4027.6, 300 sec: 3798.1). Total num frames: 626688. Throughput: 0: 1015.2. Samples: 157030. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:22:01,980][00571] Avg episode reward: [(0, '4.261')]
# [2025-01-22 16:22:06,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.8, 300 sec: 3806.9). Total num frames: 647168. Throughput: 0: 992.4. Samples: 159698. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:22:06,975][00571] Avg episode reward: [(0, '4.434')]
# [2025-01-22 16:22:11,973][00571] Fps is (10 sec: 4506.4, 60 sec: 4164.4, 300 sec: 3838.5). Total num frames: 671744. Throughput: 0: 1033.7. Samples: 167166. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:22:11,975][00571] Avg episode reward: [(0, '4.519')]
# [2025-01-22 16:22:16,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4096.0, 300 sec: 3822.9). Total num frames: 688128. Throughput: 0: 1040.2. Samples: 173058. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:16,980][00571] Avg episode reward: [(0, '4.478')]
# [2025-01-22 16:22:21,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 3830.3). Total num frames: 708608. Throughput: 0: 1009.2. Samples: 175356. Policy #0 lag: (min: 0.0, avg: 0.8, max: 1.0)
# [2025-01-22 16:22:21,976][00571] Avg episode reward: [(0, '4.458')]
# [2025-01-22 16:22:26,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 3858.9). Total num frames: 733184. Throughput: 0: 1007.0. Samples: 182080. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:26,976][00571] Avg episode reward: [(0, '4.630')]
# [2025-01-22 16:22:31,973][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.6, 300 sec: 3864.9). Total num frames: 753664. Throughput: 0: 1062.0. Samples: 189072. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:31,977][00571] Avg episode reward: [(0, '4.933')]
# [2025-01-22 16:22:36,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.5, 300 sec: 3829.8). Total num frames: 765952. Throughput: 0: 1028.8. Samples: 191226. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:36,981][00571] Avg episode reward: [(0, '4.660')]
# [2025-01-22 16:22:41,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4028.0, 300 sec: 3856.2). Total num frames: 790528. Throughput: 0: 1000.8. Samples: 197104. Policy #0 lag: (min: 0.0, avg: 0.8, max: 2.0)
# [2025-01-22 16:22:41,977][00571] Avg episode reward: [(0, '4.789')]
# [2025-01-22 16:22:46,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 3881.4). Total num frames: 815104. Throughput: 0: 1054.1. Samples: 204464. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:46,976][00571] Avg episode reward: [(0, '4.885')]
# [2025-01-22 16:22:51,973][00571] Fps is (10 sec: 4096.0, 60 sec: 4096.0, 300 sec: 3867.4). Total num frames: 831488. Throughput: 0: 1058.4. Samples: 207324. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:22:51,976][00571] Avg episode reward: [(0, '4.726')]
# [2025-01-22 16:22:56,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 3872.6). Total num frames: 851968. Throughput: 0: 994.8. Samples: 211932. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:22:56,980][00571] Avg episode reward: [(0, '4.691')]
# [2025-01-22 16:23:01,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4164.4, 300 sec: 3895.7). Total num frames: 876544. Throughput: 0: 1026.5. Samples: 219250. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:23:01,975][00571] Avg episode reward: [(0, '4.653')]
# [2025-01-22 16:23:06,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 3900.1). Total num frames: 897024. Throughput: 0: 1057.0. Samples: 222920. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:06,978][00571] Avg episode reward: [(0, '4.478')]
# [2025-01-22 16:23:11,973][00571] Fps is (10 sec: 3686.5, 60 sec: 4027.7, 300 sec: 3886.8). Total num frames: 913408. Throughput: 0: 1016.4. Samples: 227818. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:23:11,976][00571] Avg episode reward: [(0, '4.660')]
# [2025-01-22 16:23:16,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4164.3, 300 sec: 3908.3). Total num frames: 937984. Throughput: 0: 1008.5. Samples: 234456. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:16,976][00571] Avg episode reward: [(0, '4.706')]
# [2025-01-22 16:23:21,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 3928.8). Total num frames: 962560. Throughput: 0: 1042.1. Samples: 238120. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:23:21,980][00571] Avg episode reward: [(0, '4.632')]
# [2025-01-22 16:23:26,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 3899.4). Total num frames: 974848. Throughput: 0: 1038.9. Samples: 243854. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:26,978][00571] Avg episode reward: [(0, '4.639')]
# [2025-01-22 16:23:31,973][00571] Fps is (10 sec: 3276.8, 60 sec: 4027.7, 300 sec: 3903.2). Total num frames: 995328. Throughput: 0: 996.0. Samples: 249282. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:31,975][00571] Avg episode reward: [(0, '4.592')]
# [2025-01-22 16:23:36,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4232.5, 300 sec: 3922.7). Total num frames: 1019904. Throughput: 0: 1013.2. Samples: 252918. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:23:36,982][00571] Avg episode reward: [(0, '4.660')]
# [2025-01-22 16:23:41,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4164.3, 300 sec: 3926.0). Total num frames: 1040384. Throughput: 0: 1067.3. Samples: 259962. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:41,982][00571] Avg episode reward: [(0, '4.684')]
# [2025-01-22 16:23:46,978][00571] Fps is (10 sec: 3684.9, 60 sec: 4027.5, 300 sec: 3913.9). Total num frames: 1056768. Throughput: 0: 1007.2. Samples: 264578. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:23:46,979][00571] Avg episode reward: [(0, '4.743')]
# [2025-01-22 16:23:51,973][00571] Fps is (10 sec: 4096.1, 60 sec: 4164.3, 300 sec: 3932.2). Total num frames: 1081344. Throughput: 0: 1004.5. Samples: 268124. Policy #0 lag: (min: 0.0, avg: 0.4, max: 1.0)
# [2025-01-22 16:23:51,978][00571] Avg episode reward: [(0, '4.830')]
# [2025-01-22 16:23:56,975][00571] Fps is (10 sec: 4097.1, 60 sec: 4095.9, 300 sec: 3920.4). Total num frames: 1097728. Throughput: 0: 1035.5. Samples: 274418. Policy #0 lag: (min: 0.0, avg: 0.4, max: 1.0)
# [2025-01-22 16:23:56,979][00571] Avg episode reward: [(0, '4.881')]
# [2025-01-22 16:24:01,973][00571] Fps is (10 sec: 2867.2, 60 sec: 3891.2, 300 sec: 3894.8). Total num frames: 1110016. Throughput: 0: 972.4. Samples: 278212. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:24:01,979][00571] Avg episode reward: [(0, '5.098')]
# [2025-01-22 16:24:06,974][00571] Fps is (10 sec: 2867.5, 60 sec: 3822.9, 300 sec: 3884.1). Total num frames: 1126400. Throughput: 0: 939.6. Samples: 280402. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:24:06,978][00571] Avg episode reward: [(0, '5.388')]
# [2025-01-22 16:24:11,973][00571] Fps is (10 sec: 4505.6, 60 sec: 4027.7, 300 sec: 3915.5). Total num frames: 1155072. Throughput: 0: 966.6. Samples: 287350. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:24:11,975][00571] Avg episode reward: [(0, '5.376')]
# [2025-01-22 16:24:16,973][00571] Fps is (10 sec: 4915.2, 60 sec: 3959.5, 300 sec: 3984.9). Total num frames: 1175552. Throughput: 0: 1003.2. Samples: 294426. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:24:16,977][00571] Avg episode reward: [(0, '5.438')]
# [2025-01-22 16:24:21,973][00571] Fps is (10 sec: 3686.4, 60 sec: 3822.9, 300 sec: 4040.5). Total num frames: 1191936. Throughput: 0: 971.2. Samples: 296620. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:21,978][00571] Avg episode reward: [(0, '5.692')]
# [2025-01-22 16:24:26,974][00571] Fps is (10 sec: 3686.3, 60 sec: 3959.4, 300 sec: 4054.3). Total num frames: 1212416. Throughput: 0: 944.4. Samples: 302460. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:26,978][00571] Avg episode reward: [(0, '5.440')]
# [2025-01-22 16:24:31,976][00571] Fps is (10 sec: 4504.3, 60 sec: 4027.5, 300 sec: 4054.3). Total num frames: 1236992. Throughput: 0: 1009.0. Samples: 309984. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:31,979][00571] Avg episode reward: [(0, '5.488')]
# [2025-01-22 16:24:36,974][00571] Fps is (10 sec: 4096.1, 60 sec: 3891.2, 300 sec: 4054.3). Total num frames: 1253376. Throughput: 0: 995.4. Samples: 312916. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:36,976][00571] Avg episode reward: [(0, '5.922')]
# [2025-01-22 16:24:41,974][00571] Fps is (10 sec: 3687.5, 60 sec: 3891.2, 300 sec: 4068.2). Total num frames: 1273856. Throughput: 0: 960.3. Samples: 317632. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:41,976][00571] Avg episode reward: [(0, '6.107')]
# [2025-01-22 16:24:46,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4028.0, 300 sec: 4068.2). Total num frames: 1298432. Throughput: 0: 1037.7. Samples: 324908. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:46,975][00571] Avg episode reward: [(0, '5.844')]
# [2025-01-22 16:24:51,977][00571] Fps is (10 sec: 4504.0, 60 sec: 3959.2, 300 sec: 4068.2). Total num frames: 1318912. Throughput: 0: 1067.2. Samples: 328428. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:24:51,980][00571] Avg episode reward: [(0, '5.834')]
# [2025-01-22 16:24:56,974][00571] Fps is (10 sec: 3276.7, 60 sec: 3891.3, 300 sec: 4054.3). Total num frames: 1331200. Throughput: 0: 1018.2. Samples: 333170. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:24:56,981][00571] Avg episode reward: [(0, '6.065')]
# [2025-01-22 16:25:01,974][00571] Fps is (10 sec: 3687.7, 60 sec: 4096.0, 300 sec: 4054.3). Total num frames: 1355776. Throughput: 0: 1003.6. Samples: 339586. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:01,975][00571] Avg episode reward: [(0, '6.451')]
# [2025-01-22 16:25:06,974][00571] Fps is (10 sec: 4915.3, 60 sec: 4232.5, 300 sec: 4054.3). Total num frames: 1380352. Throughput: 0: 1035.4. Samples: 343214. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:25:06,976][00571] Avg episode reward: [(0, '6.742')]
# [2025-01-22 16:25:11,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4027.7, 300 sec: 4054.4). Total num frames: 1396736. Throughput: 0: 1031.7. Samples: 348886. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:11,978][00571] Avg episode reward: [(0, '6.355')]
# [2025-01-22 16:25:16,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 1417216. Throughput: 0: 989.4. Samples: 354504. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:16,978][00571] Avg episode reward: [(0, '6.171')]
# [2025-01-22 16:25:21,974][00571] Fps is (10 sec: 4505.4, 60 sec: 4164.2, 300 sec: 4068.2). Total num frames: 1441792. Throughput: 0: 1005.5. Samples: 358164. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:25:21,976][00571] Avg episode reward: [(0, '5.967')]
# [2025-01-22 16:25:26,978][00571] Fps is (10 sec: 4094.1, 60 sec: 4095.7, 300 sec: 4040.5). Total num frames: 1458176. Throughput: 0: 1048.3. Samples: 364810. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:25:26,981][00571] Avg episode reward: [(0, '5.834')]
# [2025-01-22 16:25:31,973][00571] Fps is (10 sec: 3277.0, 60 sec: 3959.7, 300 sec: 4054.4). Total num frames: 1474560. Throughput: 0: 987.7. Samples: 369356. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:25:31,976][00571] Avg episode reward: [(0, '5.764')]
# [2025-01-22 16:25:36,974][00571] Fps is (10 sec: 4097.9, 60 sec: 4096.0, 300 sec: 4054.3). Total num frames: 1499136. Throughput: 0: 991.8. Samples: 373056. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:25:36,978][00571] Avg episode reward: [(0, '6.606')]
# [2025-01-22 16:25:41,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4164.3, 300 sec: 4054.3). Total num frames: 1523712. Throughput: 0: 1050.7. Samples: 380452. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:41,976][00571] Avg episode reward: [(0, '7.209')]
# [2025-01-22 16:25:46,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 1540096. Throughput: 0: 1015.8. Samples: 385298. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:46,981][00571] Avg episode reward: [(0, '7.397')]
# [2025-01-22 16:25:51,977][00571] Fps is (10 sec: 3685.2, 60 sec: 4027.8, 300 sec: 4068.2). Total num frames: 1560576. Throughput: 0: 995.0. Samples: 387990. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:25:51,981][00571] Avg episode reward: [(0, '7.069')]
# [2025-01-22 16:25:56,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4232.6, 300 sec: 4068.2). Total num frames: 1585152. Throughput: 0: 1028.1. Samples: 395152. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:25:56,976][00571] Avg episode reward: [(0, '7.008')]
# [2025-01-22 16:26:01,973][00571] Fps is (10 sec: 4097.4, 60 sec: 4096.0, 300 sec: 4054.4). Total num frames: 1601536. Throughput: 0: 1034.7. Samples: 401064. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:26:01,976][00571] Avg episode reward: [(0, '6.909')]
# [2025-01-22 16:26:06,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4068.3). Total num frames: 1622016. Throughput: 0: 1004.3. Samples: 403358. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:26:06,979][00571] Avg episode reward: [(0, '6.941')]
# [2025-01-22 16:26:11,973][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 4082.1). Total num frames: 1646592. Throughput: 0: 1010.6. Samples: 410282. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:26:11,979][00571] Avg episode reward: [(0, '6.829')]
# [2025-01-22 16:26:16,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 1667072. Throughput: 0: 1063.5. Samples: 417212. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:26:16,976][00571] Avg episode reward: [(0, '7.096')]
# [2025-01-22 16:26:21,976][00571] Fps is (10 sec: 3275.9, 60 sec: 3959.3, 300 sec: 4054.3). Total num frames: 1679360. Throughput: 0: 1029.1. Samples: 419368. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:26:21,978][00571] Avg episode reward: [(0, '7.095')]
# [2025-01-22 16:26:26,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4096.3, 300 sec: 4068.3). Total num frames: 1703936. Throughput: 0: 992.0. Samples: 425090. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:26:26,976][00571] Avg episode reward: [(0, '7.377')]
# [2025-01-22 16:26:31,973][00571] Fps is (10 sec: 4916.5, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 1728512. Throughput: 0: 1048.1. Samples: 432464. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:26:31,975][00571] Avg episode reward: [(0, '7.370')]
# [2025-01-22 16:26:36,976][00571] Fps is (10 sec: 4095.0, 60 sec: 4095.8, 300 sec: 4054.4). Total num frames: 1744896. Throughput: 0: 1054.0. Samples: 435418. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:26:36,981][00571] Avg episode reward: [(0, '7.381')]
# [2025-01-22 16:26:41,973][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4082.1). Total num frames: 1765376. Throughput: 0: 999.7. Samples: 440140. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:26:41,980][00571] Avg episode reward: [(0, '7.900')]
# [2025-01-22 16:26:46,974][00571] Fps is (10 sec: 4506.8, 60 sec: 4164.3, 300 sec: 4082.1). Total num frames: 1789952. Throughput: 0: 1032.0. Samples: 447504. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:26:46,980][00571] Avg episode reward: [(0, '8.492')]
# [2025-01-22 16:26:51,974][00571] Fps is (10 sec: 4095.9, 60 sec: 4096.2, 300 sec: 4054.3). Total num frames: 1806336. Throughput: 0: 1057.8. Samples: 450960. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:26:51,980][00571] Avg episode reward: [(0, '8.555')]
# [2025-01-22 16:26:56,974][00571] Fps is (10 sec: 3276.6, 60 sec: 3959.4, 300 sec: 4054.4). Total num frames: 1822720. Throughput: 0: 1004.8. Samples: 455498. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:26:56,978][00571] Avg episode reward: [(0, '8.151')]
# [2025-01-22 16:27:01,974][00571] Fps is (10 sec: 4096.1, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 1847296. Throughput: 0: 996.3. Samples: 462044. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:27:01,980][00571] Avg episode reward: [(0, '8.872')]
# [2025-01-22 16:27:06,974][00571] Fps is (10 sec: 4915.5, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 1871872. Throughput: 0: 1027.8. Samples: 465616. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:06,980][00571] Avg episode reward: [(0, '9.841')]
# [2025-01-22 16:27:11,973][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 1884160. Throughput: 0: 1029.2. Samples: 471402. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:27:11,980][00571] Avg episode reward: [(0, '10.868')]
# [2025-01-22 16:27:16,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 1904640. Throughput: 0: 987.6. Samples: 476906. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:16,976][00571] Avg episode reward: [(0, '11.149')]
# [2025-01-22 16:27:21,973][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.5, 300 sec: 4054.3). Total num frames: 1929216. Throughput: 0: 1003.7. Samples: 480584. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:21,976][00571] Avg episode reward: [(0, '11.774')]
# [2025-01-22 16:27:26,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4096.0, 300 sec: 4054.3). Total num frames: 1949696. Throughput: 0: 1050.6. Samples: 487418. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:27:26,976][00571] Avg episode reward: [(0, '11.961')]
# [2025-01-22 16:27:31,973][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4068.2). Total num frames: 1966080. Throughput: 0: 985.9. Samples: 491870. Policy #0 lag: (min: 0.0, avg: 0.8, max: 2.0)
# [2025-01-22 16:27:31,976][00571] Avg episode reward: [(0, '11.784')]
# [2025-01-22 16:27:36,974][00571] Fps is (10 sec: 4095.9, 60 sec: 4096.2, 300 sec: 4068.2). Total num frames: 1990656. Throughput: 0: 988.5. Samples: 495444. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:36,978][00571] Avg episode reward: [(0, '12.824')]
# [2025-01-22 16:27:41,974][00571] Fps is (10 sec: 4915.1, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 2015232. Throughput: 0: 1052.7. Samples: 502868. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:27:41,979][00571] Avg episode reward: [(0, '13.347')]
# [2025-01-22 16:27:46,975][00571] Fps is (10 sec: 3685.9, 60 sec: 3959.4, 300 sec: 4054.3). Total num frames: 2027520. Throughput: 0: 1018.9. Samples: 507898. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:46,982][00571] Avg episode reward: [(0, '13.386')]
# [2025-01-22 16:27:51,974][00571] Fps is (10 sec: 3686.3, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 2052096. Throughput: 0: 998.0. Samples: 510528. Policy #0 lag: (min: 0.0, avg: 0.8, max: 2.0)
# [2025-01-22 16:27:51,980][00571] Avg episode reward: [(0, '15.055')]
# [2025-01-22 16:27:56,974][00571] Fps is (10 sec: 4506.3, 60 sec: 4164.3, 300 sec: 4054.3). Total num frames: 2072576. Throughput: 0: 1028.8. Samples: 517696. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:27:56,980][00571] Avg episode reward: [(0, '14.753')]
# [2025-01-22 16:28:01,974][00571] Fps is (10 sec: 4096.1, 60 sec: 4096.0, 300 sec: 4054.3). Total num frames: 2093056. Throughput: 0: 1043.7. Samples: 523874. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:28:01,983][00571] Avg episode reward: [(0, '14.748')]
# [2025-01-22 16:28:06,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 2109440. Throughput: 0: 1011.7. Samples: 526110. Policy #0 lag: (min: 0.0, avg: 0.7, max: 1.0)
# [2025-01-22 16:28:06,976][00571] Avg episode reward: [(0, '14.347')]
# [2025-01-22 16:28:11,973][00571] Fps is (10 sec: 4096.1, 60 sec: 4164.3, 300 sec: 4054.3). Total num frames: 2134016. Throughput: 0: 1010.7. Samples: 532900. Policy #0 lag: (min: 0.0, avg: 0.8, max: 2.0)
# [2025-01-22 16:28:11,986][00571] Avg episode reward: [(0, '14.651')]
# [2025-01-22 16:28:16,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 4054.3). Total num frames: 2158592. Throughput: 0: 1075.6. Samples: 540272. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:28:16,976][00571] Avg episode reward: [(0, '15.554')]
# [2025-01-22 16:28:21,974][00571] Fps is (10 sec: 4095.9, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 2174976. Throughput: 0: 1045.1. Samples: 542474. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:28:21,976][00571] Avg episode reward: [(0, '15.673')]
# [2025-01-22 16:28:26,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 2195456. Throughput: 0: 1002.7. Samples: 547988. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:28:26,976][00571] Avg episode reward: [(0, '17.094')]
# [2025-01-22 16:28:31,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 2220032. Throughput: 0: 1046.8. Samples: 555002. Policy #0 lag: (min: 0.0, avg: 0.7, max: 1.0)
# [2025-01-22 16:28:31,976][00571] Avg episode reward: [(0, '17.386')]
# [2025-01-22 16:28:36,974][00571] Fps is (10 sec: 3686.2, 60 sec: 4027.7, 300 sec: 4040.5). Total num frames: 2232320. Throughput: 0: 1055.2. Samples: 558014. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:28:36,976][00571] Avg episode reward: [(0, '17.602')]
# [2025-01-22 16:28:41,974][00571] Fps is (10 sec: 2457.7, 60 sec: 3822.9, 300 sec: 4026.6). Total num frames: 2244608. Throughput: 0: 978.8. Samples: 561742. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:28:41,976][00571] Avg episode reward: [(0, '17.515')]
# [2025-01-22 16:28:46,974][00571] Fps is (10 sec: 3276.9, 60 sec: 3959.6, 300 sec: 4012.7). Total num frames: 2265088. Throughput: 0: 954.1. Samples: 566810. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:28:46,976][00571] Avg episode reward: [(0, '17.400')]
# [2025-01-22 16:28:51,973][00571] Fps is (10 sec: 4505.6, 60 sec: 3959.5, 300 sec: 4040.5). Total num frames: 2289664. Throughput: 0: 986.8. Samples: 570518. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:28:51,975][00571] Avg episode reward: [(0, '17.974')]
# [2025-01-22 16:28:56,976][00571] Fps is (10 sec: 4095.0, 60 sec: 3891.0, 300 sec: 4054.3). Total num frames: 2306048. Throughput: 0: 975.8. Samples: 576812. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:28:56,981][00571] Avg episode reward: [(0, '18.276')]
# [2025-01-22 16:29:01,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3822.9, 300 sec: 4054.3). Total num frames: 2322432. Throughput: 0: 915.2. Samples: 581458. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:29:01,978][00571] Avg episode reward: [(0, '17.574')]
# [2025-01-22 16:29:06,974][00571] Fps is (10 sec: 4506.8, 60 sec: 4027.7, 300 sec: 4054.3). Total num frames: 2351104. Throughput: 0: 948.5. Samples: 585158. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:29:06,982][00571] Avg episode reward: [(0, '18.326')]
# [2025-01-22 16:29:11,973][00571] Fps is (10 sec: 4915.2, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 2371584. Throughput: 0: 988.0. Samples: 592448. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:29:11,976][00571] Avg episode reward: [(0, '17.350')]
# [2025-01-22 16:29:16,974][00571] Fps is (10 sec: 3276.6, 60 sec: 3754.6, 300 sec: 4040.5). Total num frames: 2383872. Throughput: 0: 936.1. Samples: 597128. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:29:16,976][00571] Avg episode reward: [(0, '16.108')]
# [2025-01-22 16:29:21,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3891.2, 300 sec: 4054.3). Total num frames: 2408448. Throughput: 0: 936.3. Samples: 600148. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:29:21,980][00571] Avg episode reward: [(0, '16.454')]
# [2025-01-22 16:29:26,974][00571] Fps is (10 sec: 4915.5, 60 sec: 3959.5, 300 sec: 4054.4). Total num frames: 2433024. Throughput: 0: 1018.7. Samples: 607582. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:29:26,981][00571] Avg episode reward: [(0, '16.834')]
# [2025-01-22 16:29:31,973][00571] Fps is (10 sec: 4096.0, 60 sec: 3823.0, 300 sec: 4054.3). Total num frames: 2449408. Throughput: 0: 1030.7. Samples: 613190. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:29:31,976][00571] Avg episode reward: [(0, '17.057')]
# [2025-01-22 16:29:36,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 2469888. Throughput: 0: 1000.3. Samples: 615532. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:29:36,981][00571] Avg episode reward: [(0, '17.467')]
# [2025-01-22 16:29:41,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4164.3, 300 sec: 4054.3). Total num frames: 2494464. Throughput: 0: 1020.7. Samples: 622740. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:29:41,981][00571] Avg episode reward: [(0, '17.126')]
# [2025-01-22 16:29:46,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 4054.4). Total num frames: 2514944. Throughput: 0: 1069.8. Samples: 629600. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:29:46,979][00571] Avg episode reward: [(0, '17.650')]
# [2025-01-22 16:29:51,973][00571] Fps is (10 sec: 3686.5, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 2531328. Throughput: 0: 1039.0. Samples: 631912. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:29:51,975][00571] Avg episode reward: [(0, '18.240')]
# [2025-01-22 16:29:56,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4164.5, 300 sec: 4068.2). Total num frames: 2555904. Throughput: 0: 1014.2. Samples: 638088. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:29:56,978][00571] Avg episode reward: [(0, '18.453')]
# [2025-01-22 16:30:01,973][00571] Fps is (10 sec: 4915.2, 60 sec: 4300.8, 300 sec: 4068.2). Total num frames: 2580480. Throughput: 0: 1068.5. Samples: 645210. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:30:01,983][00571] Avg episode reward: [(0, '20.286')]
# [2025-01-22 16:30:06,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4054.3). Total num frames: 2592768. Throughput: 0: 1056.6. Samples: 647694. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:30:06,981][00571] Avg episode reward: [(0, '22.063')]
# [2025-01-22 16:30:11,973][00571] Fps is (10 sec: 3276.8, 60 sec: 4027.7, 300 sec: 4054.3). Total num frames: 2613248. Throughput: 0: 1004.1. Samples: 652768. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:30:11,976][00571] Avg episode reward: [(0, '21.968')]
# [2025-01-22 16:30:16,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4232.6, 300 sec: 4054.3). Total num frames: 2637824. Throughput: 0: 1043.9. Samples: 660164. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:30:16,976][00571] Avg episode reward: [(0, '22.996')]
# [2025-01-22 16:30:21,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4164.3, 300 sec: 4068.3). Total num frames: 2658304. Throughput: 0: 1071.1. Samples: 663732. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:30:21,978][00571] Avg episode reward: [(0, '23.497')]
# [2025-01-22 16:30:26,974][00571] Fps is (10 sec: 3686.5, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 2674688. Throughput: 0: 1010.5. Samples: 668212. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:30:26,980][00571] Avg episode reward: [(0, '22.317')]
# [2025-01-22 16:30:31,974][00571] Fps is (10 sec: 4095.9, 60 sec: 4164.2, 300 sec: 4068.2). Total num frames: 2699264. Throughput: 0: 1011.9. Samples: 675134. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:30:31,982][00571] Avg episode reward: [(0, '21.188')]
# [2025-01-22 16:30:36,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 2723840. Throughput: 0: 1043.8. Samples: 678882. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:30:36,978][00571] Avg episode reward: [(0, '21.459')]
# [2025-01-22 16:30:41,973][00571] Fps is (10 sec: 4096.1, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 2740224. Throughput: 0: 1028.3. Samples: 684362. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:30:41,978][00571] Avg episode reward: [(0, '21.212')]
# [2025-01-22 16:30:46,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4096.0, 300 sec: 4068.3). Total num frames: 2760704. Throughput: 0: 1005.8. Samples: 690470. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:30:46,977][00571] Avg episode reward: [(0, '21.183')]
# [2025-01-22 16:30:51,975][00571] Fps is (10 sec: 4504.7, 60 sec: 4232.4, 300 sec: 4068.2). Total num frames: 2785280. Throughput: 0: 1031.4. Samples: 694108. Policy #0 lag: (min: 0.0, avg: 0.4, max: 1.0)
# [2025-01-22 16:30:51,978][00571] Avg episode reward: [(0, '22.408')]
# [2025-01-22 16:30:56,975][00571] Fps is (10 sec: 4095.4, 60 sec: 4095.9, 300 sec: 4068.2). Total num frames: 2801664. Throughput: 0: 1063.4. Samples: 700624. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:30:56,980][00571] Avg episode reward: [(0, '22.948')]
# [2025-01-22 16:31:01,974][00571] Fps is (10 sec: 3687.0, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 2822144. Throughput: 0: 1009.2. Samples: 705580. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:31:01,976][00571] Avg episode reward: [(0, '22.681')]
# [2025-01-22 16:31:06,974][00571] Fps is (10 sec: 4506.3, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 2846720. Throughput: 0: 1012.8. Samples: 709308. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:31:06,976][00571] Avg episode reward: [(0, '22.803')]
# [2025-01-22 16:31:11,975][00571] Fps is (10 sec: 4505.2, 60 sec: 4232.4, 300 sec: 4068.2). Total num frames: 2867200. Throughput: 0: 1080.9. Samples: 716852. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:31:11,983][00571] Avg episode reward: [(0, '23.989')]
# [2025-01-22 16:31:16,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4096.0, 300 sec: 4082.2). Total num frames: 2883584. Throughput: 0: 1024.8. Samples: 721252. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:31:16,980][00571] Avg episode reward: [(0, '23.410')]
# [2025-01-22 16:31:21,974][00571] Fps is (10 sec: 3686.9, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 2904064. Throughput: 0: 1007.6. Samples: 724224. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:31:21,981][00571] Avg episode reward: [(0, '23.720')]
# [2025-01-22 16:31:26,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 2928640. Throughput: 0: 1050.3. Samples: 731624. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:31:26,976][00571] Avg episode reward: [(0, '24.251')]
# [2025-01-22 16:31:31,974][00571] Fps is (10 sec: 4095.9, 60 sec: 4096.0, 300 sec: 4068.3). Total num frames: 2945024. Throughput: 0: 1030.4. Samples: 736836. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:31:31,975][00571] Avg episode reward: [(0, '23.500')]
# [2025-01-22 16:31:36,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 2961408. Throughput: 0: 1001.0. Samples: 739150. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:31:36,982][00571] Avg episode reward: [(0, '22.416')]
# [2025-01-22 16:31:41,974][00571] Fps is (10 sec: 4505.7, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 2990080. Throughput: 0: 1014.4. Samples: 746272. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:31:41,976][00571] Avg episode reward: [(0, '22.758')]
# [2025-01-22 16:31:46,976][00571] Fps is (10 sec: 4913.9, 60 sec: 4164.1, 300 sec: 4082.1). Total num frames: 3010560. Throughput: 0: 1053.5. Samples: 752992. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:31:46,982][00571] Avg episode reward: [(0, '22.432')]
# [2025-01-22 16:31:51,973][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.6, 300 sec: 4068.2). Total num frames: 3022848. Throughput: 0: 1018.6. Samples: 755144. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:31:51,979][00571] Avg episode reward: [(0, '21.949')]
# [2025-01-22 16:31:56,974][00571] Fps is (10 sec: 3687.4, 60 sec: 4096.1, 300 sec: 4068.2). Total num frames: 3047424. Throughput: 0: 985.8. Samples: 761210. Policy #0 lag: (min: 0.0, avg: 0.7, max: 2.0)
# [2025-01-22 16:31:56,979][00571] Avg episode reward: [(0, '21.958')]
# [2025-01-22 16:32:01,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 3072000. Throughput: 0: 1048.8. Samples: 768448. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:32:01,981][00571] Avg episode reward: [(0, '22.850')]
# [2025-01-22 16:32:06,974][00571] Fps is (10 sec: 4096.0, 60 sec: 4027.7, 300 sec: 4082.1). Total num frames: 3088384. Throughput: 0: 1039.1. Samples: 770982. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:32:06,976][00571] Avg episode reward: [(0, '24.575')]
# [2025-01-22 16:32:11,973][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.8, 300 sec: 4082.1). Total num frames: 3108864. Throughput: 0: 989.9. Samples: 776168. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:32:11,976][00571] Avg episode reward: [(0, '24.486')]
# [2025-01-22 16:32:16,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4164.3, 300 sec: 4082.1). Total num frames: 3133440. Throughput: 0: 1036.4. Samples: 783476. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:32:16,978][00571] Avg episode reward: [(0, '27.205')]
# [2025-01-22 16:32:21,975][00571] Fps is (10 sec: 4095.5, 60 sec: 4095.9, 300 sec: 4068.2). Total num frames: 3149824. Throughput: 0: 1060.1. Samples: 786858. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:32:21,978][00571] Avg episode reward: [(0, '26.488')]
# [2025-01-22 16:32:26,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.5, 300 sec: 4068.2). Total num frames: 3166208. Throughput: 0: 1000.7. Samples: 791302. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:32:26,977][00571] Avg episode reward: [(0, '27.881')]
# [2025-01-22 16:32:31,973][00571] Fps is (10 sec: 4096.6, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 3190784. Throughput: 0: 1000.8. Samples: 798024. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:32:31,976][00571] Avg episode reward: [(0, '26.793')]
# [2025-01-22 16:32:36,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 3215360. Throughput: 0: 1034.3. Samples: 801686. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:32:36,983][00571] Avg episode reward: [(0, '26.959')]
# [2025-01-22 16:32:41,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4068.3). Total num frames: 3227648. Throughput: 0: 1020.8. Samples: 807148. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:32:41,979][00571] Avg episode reward: [(0, '25.210')]
# [2025-01-22 16:32:46,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.9, 300 sec: 4068.2). Total num frames: 3252224. Throughput: 0: 995.2. Samples: 813230. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:32:46,978][00571] Avg episode reward: [(0, '24.179')]
# [2025-01-22 16:32:51,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4232.5, 300 sec: 4082.1). Total num frames: 3276800. Throughput: 0: 1019.9. Samples: 816878. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:32:51,981][00571] Avg episode reward: [(0, '22.810')]
# [2025-01-22 16:32:56,976][00571] Fps is (10 sec: 4095.2, 60 sec: 4095.9, 300 sec: 4068.2). Total num frames: 3293184. Throughput: 0: 1044.3. Samples: 823162. Policy #0 lag: (min: 0.0, avg: 0.4, max: 2.0)
# [2025-01-22 16:32:56,978][00571] Avg episode reward: [(0, '23.267')]
# [2025-01-22 16:33:01,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3959.5, 300 sec: 4068.2). Total num frames: 3309568. Throughput: 0: 987.1. Samples: 827896. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:33:01,975][00571] Avg episode reward: [(0, '22.055')]
# [2025-01-22 16:33:06,974][00571] Fps is (10 sec: 4096.8, 60 sec: 4096.0, 300 sec: 4068.2). Total num frames: 3334144. Throughput: 0: 995.1. Samples: 831634. Policy #0 lag: (min: 0.0, avg: 0.4, max: 1.0)
# [2025-01-22 16:33:06,980][00571] Avg episode reward: [(0, '21.020')]
# [2025-01-22 16:33:11,974][00571] Fps is (10 sec: 4915.2, 60 sec: 4164.3, 300 sec: 4068.2). Total num frames: 3358720. Throughput: 0: 1061.5. Samples: 839070. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:11,981][00571] Avg episode reward: [(0, '21.493')]
# [2025-01-22 16:33:16,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 3371008. Throughput: 0: 1014.1. Samples: 843660. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:16,978][00571] Avg episode reward: [(0, '20.739')]
# [2025-01-22 16:33:21,974][00571] Fps is (10 sec: 3276.8, 60 sec: 4027.8, 300 sec: 4054.3). Total num frames: 3391488. Throughput: 0: 996.4. Samples: 846524. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:33:21,982][00571] Avg episode reward: [(0, '19.585')]
# [2025-01-22 16:33:26,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4026.6). Total num frames: 3407872. Throughput: 0: 978.6. Samples: 851184. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:26,982][00571] Avg episode reward: [(0, '19.759')]
# [2025-01-22 16:33:31,975][00571] Fps is (10 sec: 3276.3, 60 sec: 3891.1, 300 sec: 4040.4). Total num frames: 3424256. Throughput: 0: 959.7. Samples: 856420. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:31,980][00571] Avg episode reward: [(0, '20.247')]
# [2025-01-22 16:33:36,974][00571] Fps is (10 sec: 3276.8, 60 sec: 3754.7, 300 sec: 4054.3). Total num frames: 3440640. Throughput: 0: 929.2. Samples: 858692. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:36,975][00571] Avg episode reward: [(0, '21.336')]
# [2025-01-22 16:33:41,974][00571] Fps is (10 sec: 4506.3, 60 sec: 4027.7, 300 sec: 4082.1). Total num frames: 3469312. Throughput: 0: 951.6. Samples: 865982. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:33:41,976][00571] Avg episode reward: [(0, '21.945')]
# [2025-01-22 16:33:46,974][00571] Fps is (10 sec: 4915.2, 60 sec: 3959.5, 300 sec: 4068.2). Total num frames: 3489792. Throughput: 0: 994.6. Samples: 872652. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:33:46,980][00571] Avg episode reward: [(0, '23.440')]
# [2025-01-22 16:33:51,973][00571] Fps is (10 sec: 3276.8, 60 sec: 3754.7, 300 sec: 4054.4). Total num frames: 3502080. Throughput: 0: 962.3. Samples: 874938. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:51,977][00571] Avg episode reward: [(0, '22.631')]
# [2025-01-22 16:33:56,974][00571] Fps is (10 sec: 3686.4, 60 sec: 3891.3, 300 sec: 4082.1). Total num frames: 3526656. Throughput: 0: 935.7. Samples: 881176. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:33:56,977][00571] Avg episode reward: [(0, '22.804')]
# [2025-01-22 16:34:01,975][00571] Fps is (10 sec: 4915.1, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 3551232. Throughput: 0: 993.8. Samples: 888380. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:01,977][00571] Avg episode reward: [(0, '22.280')]
# [2025-01-22 16:34:06,974][00571] Fps is (10 sec: 4096.0, 60 sec: 3891.2, 300 sec: 4054.3). Total num frames: 3567616. Throughput: 0: 985.5. Samples: 890872. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:06,976][00571] Avg episode reward: [(0, '23.531')]
# [2025-01-22 16:34:11,973][00571] Fps is (10 sec: 3686.5, 60 sec: 3822.9, 300 sec: 4082.1). Total num frames: 3588096. Throughput: 0: 997.9. Samples: 896088. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:34:11,975][00571] Avg episode reward: [(0, '23.393')]
# [2025-01-22 16:34:16,974][00571] Fps is (10 sec: 4505.5, 60 sec: 4027.7, 300 sec: 4082.1). Total num frames: 3612672. Throughput: 0: 1043.1. Samples: 903360. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:16,976][00571] Avg episode reward: [(0, '24.788')]
# [2025-01-22 16:34:21,974][00571] Fps is (10 sec: 4096.0, 60 sec: 3959.5, 300 sec: 4054.3). Total num frames: 3629056. Throughput: 0: 1068.4. Samples: 906768. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:34:21,975][00571] Avg episode reward: [(0, '25.084')]
# [2025-01-22 16:34:26,974][00571] Fps is (10 sec: 3686.5, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 3649536. Throughput: 0: 1006.9. Samples: 911294. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:34:26,979][00571] Avg episode reward: [(0, '25.693')]
# [2025-01-22 16:34:31,977][00571] Fps is (10 sec: 4094.4, 60 sec: 4095.8, 300 sec: 4068.2). Total num frames: 3670016. Throughput: 0: 1014.4. Samples: 918302. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:31,979][00571] Avg episode reward: [(0, '25.790')]
# [2025-01-22 16:34:36,974][00571] Fps is (10 sec: 4505.6, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 3694592. Throughput: 0: 1045.6. Samples: 921988. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:36,986][00571] Avg episode reward: [(0, '26.190')]
# [2025-01-22 16:34:41,974][00571] Fps is (10 sec: 3687.8, 60 sec: 3959.5, 300 sec: 4040.5). Total num frames: 3706880. Throughput: 0: 1018.4. Samples: 927006. Policy #0 lag: (min: 0.0, avg: 0.5, max: 2.0)
# [2025-01-22 16:34:41,979][00571] Avg episode reward: [(0, '25.638')]
# [2025-01-22 16:34:46,974][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 3731456. Throughput: 0: 1000.0. Samples: 933380. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:46,976][00571] Avg episode reward: [(0, '26.483')]
# [2025-01-22 16:34:51,973][00571] Fps is (10 sec: 4915.3, 60 sec: 4232.5, 300 sec: 4068.2). Total num frames: 3756032. Throughput: 0: 1025.2. Samples: 937008. Policy #0 lag: (min: 0.0, avg: 0.6, max: 2.0)
# [2025-01-22 16:34:51,980][00571] Avg episode reward: [(0, '25.060')]
# [2025-01-22 16:34:56,975][00571] Fps is (10 sec: 4095.6, 60 sec: 4095.9, 300 sec: 4040.4). Total num frames: 3772416. Throughput: 0: 1042.8. Samples: 943016. Policy #0 lag: (min: 0.0, avg: 0.5, max: 1.0)
# [2025-01-22 16:34:56,977][00571] Avg episode reward: [(0, '27.370')]
# [2025-01-22 16:35:01,973][00571] Fps is (10 sec: 3686.4, 60 sec: 4027.7, 300 sec: 4068.2). Total num frames: 3792896. Throughput: 0: 995.8. Samples: 948170. Policy #0 lag: (min: 0.0, avg: 0.6, max: 1.0)
# [2025-01-22 16:35:01,976][00571] Avg episode reward: [(0, '27.694')]
# [2025-01-22 16:35:04,379][00571] Component Batcher_0 stopped!
# [2025-01-22 16:35:04,442][00571] Component InferenceWorker_p0-w0 stopped!
# [2025-01-22 16:35:04,765][00571] Component LearnerWorker_p0 stopped!
# [2025-01-22 16:35:04,783][00571] Component RolloutWorker_w6 stopped!
# [2025-01-22 16:35:04,862][00571] Component RolloutWorker_w3 stopped!
# [2025-01-22 16:35:04,869][00571] Component RolloutWorker_w4 stopped!
# [2025-01-22 16:35:04,875][00571] Component RolloutWorker_w7 stopped!
# [2025-01-22 16:35:04,886][00571] Component RolloutWorker_w2 stopped!
# [2025-01-22 16:35:04,895][00571] Component RolloutWorker_w5 stopped!
# [2025-01-22 16:35:04,908][00571] Component RolloutWorker_w1 stopped!
# [2025-01-22 16:35:04,912][00571] Component RolloutWorker_w0 stopped!
# [2025-01-22 16:35:04,916][00571] Waiting for process learner_proc0 to stop...
# [2025-01-22 16:35:06,411][00571] Waiting for process inference_proc0-0 to join...
# [2025-01-22 16:35:06,418][00571] Waiting for process rollout_proc0 to join...
# [2025-01-22 16:35:08,318][00571] Waiting for process rollout_proc1 to join...
# [2025-01-22 16:35:08,324][00571] Waiting for process rollout_proc2 to join...
# [2025-01-22 16:35:08,327][00571] Waiting for process rollout_proc3 to join...
# [2025-01-22 16:35:08,332][00571] Waiting for process rollout_proc4 to join...
# [2025-01-22 16:35:08,336][00571] Waiting for process rollout_proc5 to join...
# [2025-01-22 16:35:08,341][00571] Waiting for process rollout_proc6 to join...
# [2025-01-22 16:35:08,343][00571] Waiting for process rollout_proc7 to join...
# [2025-01-22 16:35:08,347][00571] Batcher 0 profile tree view:
# batching: 24.3762, releasing_batches: 0.0223
# [2025-01-22 16:35:08,349][00571] InferenceWorker_p0-w0 profile tree view:
# wait_policy: 0.0000
#   wait_policy_total: 398.5033
# update_model: 7.6377
#   weight_update: 0.0012
# one_step: 0.0024
#   handle_policy_step: 510.0801
#     deserialize: 12.5907, stack: 2.7509, obs_to_device_normalize: 110.0886, forward: 259.9617, send_messages: 24.4917
#     prepare_outputs: 78.5141
#       to_cpu: 49.9092
# [2025-01-22 16:35:08,351][00571] Learner 0 profile tree view:
# misc: 0.0032, prepare_batch: 13.6464
# train: 70.7627
#   epoch_init: 0.0068, minibatch_init: 0.0122, losses_postprocess: 0.6002, kl_divergence: 0.5955, after_optimizer: 31.6053
#   calculate_losses: 25.7129
#     losses_init: 0.0053, forward_head: 1.2737, bptt_initial: 17.4554, tail: 0.9900, advantages_returns: 0.2405, losses: 3.7541
#     bptt: 1.7511
#       bptt_forward_core: 1.6765
#   update: 11.6600
#     clip: 0.7876
# [2025-01-22 16:35:08,353][00571] RolloutWorker_w0 profile tree view:
# wait_for_trajectories: 0.2393, enqueue_policy_requests: 99.0683, env_step: 738.8281, overhead: 10.7566, complete_rollouts: 6.6036
# save_policy_outputs: 16.6408
#   split_output_tensors: 6.3997
# [2025-01-22 16:35:08,354][00571] RolloutWorker_w7 profile tree view:
# wait_for_trajectories: 0.3052, enqueue_policy_requests: 102.1527, env_step: 738.1783, overhead: 10.6059, complete_rollouts: 6.0242
# save_policy_outputs: 16.9344
#   split_output_tensors: 6.4971
# [2025-01-22 16:35:08,355][00571] Loop Runner_EvtLoop terminating...
# [2025-01-22 16:35:08,356][00571] Runner profile tree view:
# main_loop: 976.4160
# [2025-01-22 16:35:08,357][00571] Collected {0: 3805184}, FPS: 3897.1

# %% [markdown]
# ## Let's take a look at the performance of the trained policy and output a video of the agent.

# %%
from sample_factory.enjoy import enjoy
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10"], evaluation=True)
status = enjoy(cfg)
# Out:
# [2025-01-22 16:35:08,775][00571] Loading existing experiment configuration from /content/train_dir/default_experiment/config.json
# [2025-01-22 16:35:08,778][00571] Overriding arg 'num_workers' with value 1 passed from command line
# [2025-01-22 16:35:08,780][00571] Adding new argument 'no_render'=True that is not in the saved config file!
# [2025-01-22 16:35:08,783][00571] Adding new argument 'save_video'=True that is not in the saved config file!
# [2025-01-22 16:35:08,786][00571] Adding new argument 'video_frames'=1000000000.0 that is not in the saved config file!
# [2025-01-22 16:35:08,787][00571] Adding new argument 'video_name'=None that is not in the saved config file!
# [2025-01-22 16:35:08,788][00571] Adding new argument 'max_num_frames'=1000000000.0 that is not in the saved config file!
# [2025-01-22 16:35:08,793][00571] Adding new argument 'max_num_episodes'=10 that is not in the saved config file!
# [2025-01-22 16:35:08,794][00571] Adding new argument 'push_to_hub'=False that is not in the saved config file!
# [2025-01-22 16:35:08,796][00571] Adding new argument 'hf_repository'=None that is not in the saved config file!
# [2025-01-22 16:35:08,798][00571] Adding new argument 'policy_index'=0 that is not in the saved config file!
# [2025-01-22 16:35:08,800][00571] Adding new argument 'eval_deterministic'=False that is not in the saved config file!
# [2025-01-22 16:35:08,801][00571] Adding new argument 'train_script'=None that is not in the saved config file!
# [2025-01-22 16:35:08,802][00571] Adding new argument 'enjoy_script'=None that is not in the saved config file!
# [2025-01-22 16:35:08,803][00571] Using frameskip 1 and render_action_repeat=4 for evaluation
# [2025-01-22 16:35:08,842][00571] Doom resolution: 160x120, resize resolution: (128, 72)
# /usr/local/lib/python3.11/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_agents to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_agents` for environment variables or `env.get_wrapper_attr('num_agents')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.is_multiagent to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.is_multiagent` for environment variables or `env.get_wrapper_attr('is_multiagent')` that will search the reminding wrappers.
#   logger.warn(
# [2025-01-22 16:35:08,846][00571] RunningMeanStd input shape: (3, 72, 128)
# [2025-01-22 16:35:08,849][00571] RunningMeanStd input shape: (1,)
# [2025-01-22 16:35:08,866][00571] ConvEncoder: input_channels=3
# [2025-01-22 16:35:08,980][00571] Conv encoder output size: 512
# [2025-01-22 16:35:08,982][00571] Policy head output size: 512
# [2025-01-22 16:35:09,154][00571] Loading state from checkpoint /content/train_dir/default_experiment/checkpoint_p0/checkpoint_000000929_3805184.pth...
# /usr/local/lib/python3.11/dist-packages/sample_factory/algo/learning/learner.py:281: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_dict = torch.load(latest_checkpoint, map_location=device)
# [2025-01-22 16:35:10,070][00571] Num frames 100...
# [2025-01-22 16:35:10,237][00571] Num frames 200...
# [2025-01-22 16:35:10,402][00571] Num frames 300...
# [2025-01-22 16:35:10,569][00571] Num frames 400...
# [2025-01-22 16:35:10,748][00571] Num frames 500...
# [2025-01-22 16:35:10,938][00571] Num frames 600...
# [2025-01-22 16:35:11,129][00571] Num frames 700...
# [2025-01-22 16:35:11,302][00571] Num frames 800...
# [2025-01-22 16:35:11,475][00571] Num frames 900...
# [2025-01-22 16:35:11,649][00571] Num frames 1000...
# [2025-01-22 16:35:11,829][00571] Num frames 1100...
# [2025-01-22 16:35:11,978][00571] Avg episode rewards: #0: 31.520, true rewards: #0: 11.520
# [2025-01-22 16:35:11,980][00571] Avg episode reward: 31.520, avg true_objective: 11.520
# [2025-01-22 16:35:12,070][00571] Num frames 1200...
# [2025-01-22 16:35:12,234][00571] Num frames 1300...
# [2025-01-22 16:35:12,364][00571] Num frames 1400...
# [2025-01-22 16:35:12,492][00571] Num frames 1500...
# [2025-01-22 16:35:12,619][00571] Num frames 1600...
# [2025-01-22 16:35:12,756][00571] Num frames 1700...
# [2025-01-22 16:35:12,885][00571] Num frames 1800...
# [2025-01-22 16:35:13,013][00571] Num frames 1900...
# [2025-01-22 16:35:13,152][00571] Num frames 2000...
# [2025-01-22 16:35:13,278][00571] Num frames 2100...
# [2025-01-22 16:35:13,408][00571] Num frames 2200...
# [2025-01-22 16:35:13,540][00571] Num frames 2300...
# [2025-01-22 16:35:13,672][00571] Num frames 2400...
# [2025-01-22 16:35:13,809][00571] Num frames 2500...
# [2025-01-22 16:35:13,937][00571] Num frames 2600...
# [2025-01-22 16:35:14,067][00571] Num frames 2700...
# [2025-01-22 16:35:14,209][00571] Num frames 2800...
# [2025-01-22 16:35:14,336][00571] Num frames 2900...
# [2025-01-22 16:35:14,470][00571] Num frames 3000...
# [2025-01-22 16:35:14,602][00571] Num frames 3100...
# [2025-01-22 16:35:14,748][00571] Num frames 3200...
# [2025-01-22 16:35:14,871][00571] Avg episode rewards: #0: 46.259, true rewards: #0: 16.260
# [2025-01-22 16:35:14,872][00571] Avg episode reward: 46.259, avg true_objective: 16.260
# [2025-01-22 16:35:14,937][00571] Num frames 3300...
# [2025-01-22 16:35:15,063][00571] Num frames 3400...
# [2025-01-22 16:35:15,200][00571] Num frames 3500...
# [2025-01-22 16:35:15,333][00571] Num frames 3600...
# [2025-01-22 16:35:15,435][00571] Avg episode rewards: #0: 32.786, true rewards: #0: 12.120
# [2025-01-22 16:35:15,436][00571] Avg episode reward: 32.786, avg true_objective: 12.120
# [2025-01-22 16:35:15,520][00571] Num frames 3700...
# [2025-01-22 16:35:15,653][00571] Num frames 3800...
# [2025-01-22 16:35:15,793][00571] Num frames 3900...
# [2025-01-22 16:35:15,926][00571] Num frames 4000...
# [2025-01-22 16:35:16,054][00571] Num frames 4100...
# [2025-01-22 16:35:16,184][00571] Num frames 4200...
# [2025-01-22 16:35:16,323][00571] Num frames 4300...
# [2025-01-22 16:35:16,453][00571] Num frames 4400...
# [2025-01-22 16:35:16,584][00571] Num frames 4500...
# [2025-01-22 16:35:16,722][00571] Num frames 4600...
# [2025-01-22 16:35:16,850][00571] Num frames 4700...
# [2025-01-22 16:35:17,003][00571] Num frames 4800...
# [2025-01-22 16:35:17,151][00571] Num frames 4900...
# [2025-01-22 16:35:17,233][00571] Avg episode rewards: #0: 32.540, true rewards: #0: 12.290
# [2025-01-22 16:35:17,235][00571] Avg episode reward: 32.540, avg true_objective: 12.290
# [2025-01-22 16:35:17,345][00571] Num frames 5000...
# [2025-01-22 16:35:17,472][00571] Num frames 5100...
# [2025-01-22 16:35:17,603][00571] Num frames 5200...
# [2025-01-22 16:35:17,737][00571] Num frames 5300...
# [2025-01-22 16:35:17,864][00571] Num frames 5400...
# [2025-01-22 16:35:17,952][00571] Avg episode rewards: #0: 27.650, true rewards: #0: 10.850
# [2025-01-22 16:35:17,953][00571] Avg episode reward: 27.650, avg true_objective: 10.850
# [2025-01-22 16:35:18,048][00571] Num frames 5500...
# [2025-01-22 16:35:18,176][00571] Num frames 5600...
# [2025-01-22 16:35:18,312][00571] Num frames 5700...
# [2025-01-22 16:35:18,438][00571] Num frames 5800...
# [2025-01-22 16:35:18,566][00571] Num frames 5900...
# [2025-01-22 16:35:18,699][00571] Num frames 6000...
# [2025-01-22 16:35:18,884][00571] Avg episode rewards: #0: 24.995, true rewards: #0: 10.162
# [2025-01-22 16:35:18,886][00571] Avg episode reward: 24.995, avg true_objective: 10.162
# [2025-01-22 16:35:18,893][00571] Num frames 6100...
# [2025-01-22 16:35:19,032][00571] Num frames 6200...
# [2025-01-22 16:35:19,170][00571] Num frames 6300...
# [2025-01-22 16:35:19,314][00571] Num frames 6400...
# [2025-01-22 16:35:19,445][00571] Num frames 6500...
# [2025-01-22 16:35:19,578][00571] Num frames 6600...
# [2025-01-22 16:35:19,711][00571] Num frames 6700...
# [2025-01-22 16:35:19,844][00571] Num frames 6800...
# [2025-01-22 16:35:19,944][00571] Avg episode rewards: #0: 23.620, true rewards: #0: 9.763
# [2025-01-22 16:35:19,945][00571] Avg episode reward: 23.620, avg true_objective: 9.763
# [2025-01-22 16:35:20,031][00571] Num frames 6900...
# [2025-01-22 16:35:20,157][00571] Num frames 7000...
# [2025-01-22 16:35:20,287][00571] Num frames 7100...
# [2025-01-22 16:35:20,420][00571] Num frames 7200...
# [2025-01-22 16:35:20,501][00571] Avg episode rewards: #0: 21.147, true rewards: #0: 9.022
# [2025-01-22 16:35:20,504][00571] Avg episode reward: 21.147, avg true_objective: 9.022
# [2025-01-22 16:35:20,610][00571] Num frames 7300...
# [2025-01-22 16:35:20,748][00571] Num frames 7400...
# [2025-01-22 16:35:20,877][00571] Num frames 7500...
# [2025-01-22 16:35:21,007][00571] Num frames 7600...
# [2025-01-22 16:35:21,139][00571] Num frames 7700...
# [2025-01-22 16:35:21,271][00571] Num frames 7800...
# [2025-01-22 16:35:21,408][00571] Num frames 7900...
# [2025-01-22 16:35:21,540][00571] Num frames 8000...
# [2025-01-22 16:35:21,667][00571] Num frames 8100...
# [2025-01-22 16:35:21,798][00571] Avg episode rewards: #0: 21.284, true rewards: #0: 9.062
# [2025-01-22 16:35:21,800][00571] Avg episode reward: 21.284, avg true_objective: 9.062
# [2025-01-22 16:35:21,856][00571] Num frames 8200...
# [2025-01-22 16:35:21,982][00571] Num frames 8300...
# [2025-01-22 16:35:22,108][00571] Num frames 8400...
# [2025-01-22 16:35:22,262][00571] Num frames 8500...
# [2025-01-22 16:35:22,457][00571] Num frames 8600...
# [2025-01-22 16:35:22,629][00571] Num frames 8700...
# [2025-01-22 16:35:22,800][00571] Num frames 8800...
# [2025-01-22 16:35:22,906][00571] Avg episode rewards: #0: 20.328, true rewards: #0: 8.828
# [2025-01-22 16:35:22,910][00571] Avg episode reward: 20.328, avg true_objective: 8.828
# [2025-01-22 16:36:15,745][00571] Replay video saved to /content/train_dir/default_experiment/replay.mp4!

# %% [markdown]
# ## Now lets visualize the performance of the agent

# %%
from base64 import b64encode
from IPython.display import HTML

mp4 = open('/content/train_dir/default_experiment/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# The agent has learned something, but its performance could be better. We would clearly need to train for longer. But let's upload this model to the Hub.

# %% [markdown]
# ## Now lets upload your checkpoint and video to the Hugging Face Hub

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store

# %%
from sample_factory.enjoy import enjoy

hf_username = "ThomasSimonini" # insert your HuggingFace username here

cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10", "--max_num_frames=100000", "--push_to_hub", f"--hf_repository={hf_username}/rl_course_vizdoom_health_gathering_supreme"], evaluation=True)
status = enjoy(cfg)

# %% [markdown]
# ## Let's load another model

# %% [markdown]
# This agent's performance was good, but can do better! Let's download and visualize an agent trained for 10B timesteps from the hub.

# %%
#download the agent from the hub
# !python -m sample_factory.huggingface.load_from_hub -r edbeeching/doom_health_gathering_supreme_2222 -d ./train_dir

# %%
# !ls train_dir/doom_health_gathering_supreme_2222

# %%
env = "doom_health_gathering_supreme"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=10", "--experiment=doom_health_gathering_supreme_2222", "--train_dir=train_dir"], evaluation=True)
status = enjoy(cfg)

# %%
mp4 = open('/content/train_dir/doom_health_gathering_supreme_2222/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# ## Some additional challenges 🏆: Doom Deathmatch
#
# Training an agent to play a Doom deathmatch **takes many hours on a more beefy machine than is available in Colab**.
#
# Fortunately, we have have **already trained an agent in this scenario and it is available in the 🤗 Hub!** Let’s download the model and visualize the agent’s performance.

# %%
# Download the agent from the hub
# !python -m sample_factory.huggingface.load_from_hub -r edbeeching/doom_deathmatch_bots_2222 -d ./train_dir

# %% [markdown]
# Given the agent plays for a long time the video generation can take **10 minutes**.

# %%
from sample_factory.enjoy import enjoy
register_vizdoom_components()
env = "doom_deathmatch_bots"
cfg = parse_vizdoom_cfg(argv=[f"--env={env}", "--num_workers=1", "--save_video", "--no_render", "--max_num_episodes=1", "--experiment=doom_deathmatch_bots_2222", "--train_dir=train_dir"], evaluation=True)
status = enjoy(cfg)
mp4 = open('/content/train_dir/doom_deathmatch_bots_2222/replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# You **can try to train your agent in this environment** using the code above, but not on colab.
# **Good luck 🤞**

# %% [markdown]
# If you prefer an easier scenario, **why not try training in another ViZDoom scenario such as `doom_deadly_corridor` or `doom_defend_the_center`.**
#
#
#
# ---
#
#
# This concludes the last unit. But we are not finished yet! 🤗 The following **bonus section include some of the most interesting, advanced and cutting edge work in Deep Reinforcement Learning**.
#
# ## Keep learning, stay awesome 🤗
